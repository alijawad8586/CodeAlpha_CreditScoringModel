# %% [markdown]
# # Credit Scoring Model
# German Credit classification with feature engineering, three models, evaluation, artifact saving, and a Streamlit deployment.

# %%
from train_model import load_data
X, y, raw_columns = load_data()
print('Features:', X.shape)
print(y.value_counts())
X.head()

# %% [markdown]
# ## Engineered features
# `load_data()` adds monthly credit burden, age group, and credit per existing account while preserving the original app-input columns.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.20, random_state=42, stratify=y
)
print(X_train.shape, X_test.shape)
print(y_train.value_counts())

# %% [markdown]
# ## Train, compare, and save
# The shared module fits Logistic Regression, Decision Tree, and Random Forest and selects the highest ROC-AUC model.

# %%
from train_model import train_and_save
results = train_and_save()
results

# %% [markdown]
# ## Prediction
# The saved object is a complete preprocessing and classifier pipeline.

# %%
import joblib
model = joblib.load('credit_scoring_model.pkl')
sample = X_test.iloc[[0]]
probability = model.predict_proba(sample)[0, 1]
{'prediction': 'High Risk' if model.predict(sample)[0] else 'Low Risk', 'risk_probability': round(probability * 100, 2)}
